# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy

# %%
lats = np.random.uniform(-90.00, 90.00, size=1500)
lngs = np.random.uniform(-180.00, 180.00, size=1500)
lats_lngs = zip(lats, lngs)

# %%
coordinates = list(lats_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 608

# %%
import requests as req
from config import weather_api_key
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=c9cd62aa021e48d1a6aeec3c6b44050c

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | deputatskiy
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | santiago de chuco
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | srednekolymsk
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | lorengau
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | khasan
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | luanda
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | annau
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | vila velha
# Processing Record 31 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 1 | mjolby
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | ha tinh
# Processing Record 35 of Set 1 | gushikawa
# Processing Record 36 of Set 1 | inhapim
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | pangnirtung
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | ust-charyshskaya pristan
# Processing Record 43 of Set 1 | corinth
# Processing Record 44 of Set 1 | outjo
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | sibolga
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | orlik
# Processing Record 2 of Set 2 | mahon
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | madimba
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | scottsboro
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | tekirdag
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | meulaboh
# Processing Record 12 of Set 2 | mikkeli
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | iskitim
# Processing Record 19 of Set 2 | zhuhai
# Processing Record 20 of Set 2 | plaridel
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | half moon bay
# Processing Record 23 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 2 | shimoda
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | stavyshche
# Processing Record 27 of Set 2 | trinidad
# Processing Record 28 of Set 2 | severo-kurilsk
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | grindavik
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | wanning
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | osoyoos
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | malatya
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | suez
# Processing Record 43 of Set 2 | ahipara
# Processing Record 44 of Set 2 | moranbah
# Processing Record 45 of Set 2 | charters towers
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | lasa
# Processing Record 49 of Set 2 | caborca
# Processing Record 50 of Set 2 | hualmay
# Processing Record 1 of Set 3 | kolvereid
# Processing Record 2 of Set 3 | jumla
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | zyryanka
# Processing Record 7 of Set 3 | mumford
# Processing Record 8 of Set 3 | port lincoln
# Processing Record 9 of Set 3 | sitka
# Processing Record 10 of Set 3 | opuwo
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | smithers
# Processing Record 14 of Set 3 | kolda
# Processing Record 15 of Set 3 | almazar
# Processing Record 16 of Set 3 | strezhevoy
# Processing Record 17 of Set 3 | stokmarknes
# Processing Record 18 of Set 3 | pimpri
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | richards bay
# Processing Record 23 of Set 3 | abapo
# Processing Record 24 of Set 3 | sillamae
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | zeya
# Processing Record 27 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | shingu
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | tefe
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | phan thiet
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | tokur
# Processing Record 37 of Set 3 | kieta
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 3 | barabai
# Processing Record 41 of Set 3 | kaduna
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | gwadar
# Processing Record 45 of Set 3 | havoysund
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | dunedin
# Processing Record 48 of Set 3 | batagay-alyta
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | dilla
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | vidim
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | vao
# Processing Record 7 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 8 of Set 4 | porto novo
# Processing Record 9 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 4 | naryan-mar
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | alenquer
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | kushima
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | eura
# Processing Record 17 of Set 4 | agadir
# Processing Record 18 of Set 4 | wajir
# Processing Record 19 of Set 4 | nurota
# Processing Record 20 of Set 4 | saint-augustin
# Processing Record 21 of Set 4 | bunia
# Processing Record 22 of Set 4 | manadhoo
# Processing Record 23 of Set 4 | yangambi
# Processing Record 24 of Set 4 | matay
# Processing Record 25 of Set 4 | bom jardim
# Processing Record 26 of Set 4 | vallenar
# Processing Record 27 of Set 4 | golden
# Processing Record 28 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 29 of Set 4 | emirdag
# Processing Record 30 of Set 4 | pahrump
# Processing Record 31 of Set 4 | rocha
# Processing Record 32 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 4 | canavieiras
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | moerai
# Processing Record 37 of Set 4 | batagay
# Processing Record 38 of Set 4 | damietta
# Processing Record 39 of Set 4 | shchigry
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | yurla
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | morondava
# Processing Record 44 of Set 4 | abu dhabi
# Processing Record 45 of Set 4 | yumen
# Processing Record 46 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 4 | cabo rojo
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | oshikango
# Processing Record 1 of Set 5 | mayo
# Processing Record 2 of Set 5 | umm lajj
# Processing Record 3 of Set 5 | bontang
# Processing Record 4 of Set 5 | santa rosalia
# Processing Record 5 of Set 5 | grand-santi
# Processing Record 6 of Set 5 | santa cruz do rio pardo
# Processing Record 7 of Set 5 | cabanas
# Processing Record 8 of Set 5 | lima
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | ouadda
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | kapaa
# Processing Record 13 of Set 5 | christchurch
# Processing Record 14 of Set 5 | barra patuca
# Processing Record 15 of Set 5 | contai
# Processing Record 16 of Set 5 | avera
# Processing Record 17 of Set 5 | bathsheba
# Processing Record 18 of Set 5 | hofn
# Processing Record 19 of Set 5 | mosquera
# Processing Record 20 of Set 5 | krasnoselkup
# Processing Record 21 of Set 5 | puerto leguizamo
# Processing Record 22 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 5 | cabedelo
# Processing Record 24 of Set 5 | chuy
# Processing Record 25 of Set 5 | olovyannaya
# Processing Record 26 of Set 5 | polovinnoye
# Processing Record 27 of Set 5 | olga
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | dongsheng
# Processing Record 32 of Set 5 | callaway
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | ios
# Processing Record 35 of Set 5 | alto araguaia
# Processing Record 36 of Set 5 | westport
# Processing Record 37 of Set 5 | sur
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | marsh harbour
# Processing Record 40 of Set 5 | kawalu
# Processing Record 41 of Set 5 | mogok
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | phalaborwa
# Processing Record 44 of Set 5 | muscat
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | buraydah
# Processing Record 47 of Set 5 | tucumcari
# Processing Record 48 of Set 5 | clyde river
# Processing Record 49 of Set 5 | okha
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 6 | agucadoura
# Processing Record 3 of Set 6 | san juan de uraba
# Processing Record 4 of Set 6 | manacapuru
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | ewa beach
# Processing Record 7 of Set 6 | juybar
# Processing Record 8 of Set 6 | yelkhovka
# Processing Record 9 of Set 6 | ibia
# Processing Record 10 of Set 6 | kanel
# Processing Record 11 of Set 6 | elhovo
# Processing Record 12 of Set 6 | cheremnoye
# Processing Record 13 of Set 6 | aksu
# Processing Record 14 of Set 6 | whitehorse
# Processing Record 15 of Set 6 | shunyi
# Processing Record 16 of Set 6 | barcelos
# Processing Record 17 of Set 6 | manitouwadge
# Processing Record 18 of Set 6 | gweru
# Processing Record 19 of Set 6 | biltine
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | sarakhs
# Processing Record 22 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 6 | vaasa
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | spencer
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | kamensk-uralskiy
# Processing Record 28 of Set 6 | bethel
# Processing Record 29 of Set 6 | kampene
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | todos santos
# Processing Record 32 of Set 6 | luderitz
# Processing Record 33 of Set 6 | nizhnevartovsk
# Processing Record 34 of Set 6 | soe
# Processing Record 35 of Set 6 | atar
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | jiwani
# Processing Record 39 of Set 6 | salalah
# Processing Record 40 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 6 | acarau
# Processing Record 42 of Set 6 | henderson
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | termoli
# Processing Record 45 of Set 6 | georgetown
# Processing Record 46 of Set 6 | mana
# Processing Record 47 of Set 6 | qom
# Processing Record 48 of Set 6 | keti bandar
# Processing Record 49 of Set 6 | najran
# Processing Record 50 of Set 6 | verkhnevilyuysk
# Processing Record 1 of Set 7 | laela
# Processing Record 2 of Set 7 | tevaitoa
# Processing Record 3 of Set 7 | kharp
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | marsa matruh
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | savannah bight
# Processing Record 8 of Set 7 | lukiv
# Processing Record 9 of Set 7 | quatre cocos
# Processing Record 10 of Set 7 | senneterre
# Processing Record 11 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 7 | ringebu
# Processing Record 13 of Set 7 | russell
# Processing Record 14 of Set 7 | iskateley
# Processing Record 15 of Set 7 | vestmannaeyjar
# Processing Record 16 of Set 7 | great falls
# Processing Record 17 of Set 7 | suntar
# Processing Record 18 of Set 7 | tual
# Processing Record 19 of Set 7 | lokhvytsya
# Processing Record 20 of Set 7 | toma
# Processing Record 21 of Set 7 | staritsa
# Processing Record 22 of Set 7 | pecos
# Processing Record 23 of Set 7 | la ronge
# Processing Record 24 of Set 7 | egvekinot
# Processing Record 25 of Set 7 | raudeberg
# Processing Record 26 of Set 7 | myanaung
# Processing Record 27 of Set 7 | cap malheureux
# Processing Record 28 of Set 7 | zhanakorgan
# Processing Record 29 of Set 7 | orel-izumrud
# Processing Record 30 of Set 7 | tasiilaq
# Processing Record 31 of Set 7 | oranjemund
# Processing Record 32 of Set 7 | mozarlandia
# Processing Record 33 of Set 7 | houma
# Processing Record 34 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 7 | baijiantan
# Processing Record 36 of Set 7 | hrodna
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | kapit
# Processing Record 39 of Set 7 | nanortalik
# Processing Record 40 of Set 7 | galesong
# Processing Record 41 of Set 7 | abha
# Processing Record 42 of Set 7 | sungaipenuh
# Processing Record 43 of Set 7 | chateaudun
# Processing Record 44 of Set 7 | pacifica
# Processing Record 45 of Set 7 | skibbereen
# Processing Record 46 of Set 7 | varhaug
# Processing Record 47 of Set 7 | ugoofaaru
# Processing Record 48 of Set 7 | llandrindod wells
# Processing Record 49 of Set 7 | antalaha
# Processing Record 50 of Set 7 | dickson
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | sovetskiy
# Processing Record 3 of Set 8 | rawson
# Processing Record 4 of Set 8 | caravelas
# Processing Record 5 of Set 8 | dicabisagan
# Processing Record 6 of Set 8 | kandi
# Processing Record 7 of Set 8 | churapcha
# Processing Record 8 of Set 8 | kahului
# Processing Record 9 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 8 | tres picos
# Processing Record 11 of Set 8 | ternate
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | karpogory
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | nangong
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | san pedro
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | manhumirim
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | una
# Processing Record 22 of Set 8 | ocampo
# Processing Record 23 of Set 8 | bilma
# Processing Record 24 of Set 8 | benguela
# Processing Record 25 of Set 8 | benghazi
# Processing Record 26 of Set 8 | juruti
# Processing Record 27 of Set 8 | talcahuano
# Processing Record 28 of Set 8 | hailar
# Processing Record 29 of Set 8 | milkovo
# Processing Record 30 of Set 8 | skegness
# Processing Record 31 of Set 8 | waipawa
# Processing Record 32 of Set 8 | sakakah
# Processing Record 33 of Set 8 | college
# Processing Record 34 of Set 8 | bar harbor
# Processing Record 35 of Set 8 | okhotsk
# Processing Record 36 of Set 8 | surt
# Processing Record 37 of Set 8 | henties bay
# Processing Record 38 of Set 8 | la asuncion
# Processing Record 39 of Set 8 | akhalgori
# Processing Record 40 of Set 8 | qiongshan
# Processing Record 41 of Set 8 | tuatapere
# Processing Record 42 of Set 8 | san luis
# Processing Record 43 of Set 8 | klaksvik
# Processing Record 44 of Set 8 | inarcs
# Processing Record 45 of Set 8 | mindelo
# Processing Record 46 of Set 8 | dalvik
# Processing Record 47 of Set 8 | marsaxlokk
# Processing Record 48 of Set 8 | plouzane
# Processing Record 49 of Set 8 | yerbogachen
# Processing Record 50 of Set 8 | salym
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | graaff-reinet
# Processing Record 3 of Set 9 | marihatag
# Processing Record 4 of Set 9 | tazovskiy
# Processing Record 5 of Set 9 | fort nelson
# Processing Record 6 of Set 9 | arawa
# Processing Record 7 of Set 9 | northam
# Processing Record 8 of Set 9 | inhambane
# Processing Record 9 of Set 9 | barinas
# Processing Record 10 of Set 9 | kiunga
# Processing Record 11 of Set 9 | youkounkoun
# Processing Record 12 of Set 9 | moron
# Processing Record 13 of Set 9 | krasnoye
# Processing Record 14 of Set 9 | stantsionno-oyashinskiy
# Processing Record 15 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | farafangana
# Processing Record 18 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 9 | moose factory
# Processing Record 21 of Set 9 | ambilobe
# Processing Record 22 of Set 9 | caorle
# Processing Record 23 of Set 9 | araguatins
# City not found. Skipping...
# Processing Record 24 of Set 9 | nuuk
# Processing Record 25 of Set 9 | chimbote
# Processing Record 26 of Set 9 | magadan
# Processing Record 27 of Set 9 | shiyan
# Processing Record 28 of Set 9 | aberdeen
# Processing Record 29 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 9 | bafia
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | waingapu
# Processing Record 33 of Set 9 | morro bay
# Processing Record 34 of Set 9 | manokwari
# Processing Record 35 of Set 9 | knysna
# Processing Record 36 of Set 9 | pinega
# Processing Record 37 of Set 9 | sao felix do xingu
# Processing Record 38 of Set 9 | yeniseysk
# Processing Record 39 of Set 9 | nakamura
# Processing Record 40 of Set 9 | high level
# Processing Record 41 of Set 9 | liberal
# Processing Record 42 of Set 9 | namibe
# Processing Record 43 of Set 9 | rafaela
# Processing Record 44 of Set 9 | tabas
# Processing Record 45 of Set 9 | pasni
# Processing Record 46 of Set 9 | amapa
# Processing Record 47 of Set 9 | husavik
# Processing Record 48 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 9 | caucaia
# Processing Record 50 of Set 9 | bambanglipuro
# Processing Record 1 of Set 10 | esperance
# Processing Record 2 of Set 10 | raigarh
# Processing Record 3 of Set 10 | villaviciosa
# Processing Record 4 of Set 10 | nhulunbuy
# Processing Record 5 of Set 10 | la plata
# Processing Record 6 of Set 10 | ulyanovo
# City not found. Skipping...
# Processing Record 7 of Set 10 | codajas
# Processing Record 8 of Set 10 | gornyy
# Processing Record 9 of Set 10 | hami
# Processing Record 10 of Set 10 | damghan
# Processing Record 11 of Set 10 | desur
# Processing Record 12 of Set 10 | gracac
# Processing Record 13 of Set 10 | ciudad bolivar
# Processing Record 14 of Set 10 | honningsvag
# Processing Record 15 of Set 10 | tomatlan
# Processing Record 16 of Set 10 | xichang
# Processing Record 17 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 18 of Set 10 | miramar
# Processing Record 19 of Set 10 | mogadishu
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | ekhabi
# Processing Record 22 of Set 10 | yantzaza
# Processing Record 23 of Set 10 | tautira
# Processing Record 24 of Set 10 | gat
# Processing Record 25 of Set 10 | praia da vitoria
# Processing Record 26 of Set 10 | bogorodskoye
# Processing Record 27 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 10 | manggar
# Processing Record 29 of Set 10 | flin flon
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | yining
# Processing Record 32 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | nushki
# Processing Record 35 of Set 10 | baykit
# Processing Record 36 of Set 10 | ladario
# Processing Record 37 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | omsukchan
# Processing Record 39 of Set 10 | yilan
# Processing Record 40 of Set 10 | ngunguru
# Processing Record 41 of Set 10 | boa vista
# Processing Record 42 of Set 10 | poum
# Processing Record 43 of Set 10 | north branch
# Processing Record 44 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 10 | anori
# Processing Record 46 of Set 10 | dusetos
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | umea
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 50 of Set 10 | hamilton
# Processing Record 1 of Set 11 | quepos
# Processing Record 2 of Set 11 | liwale
# Processing Record 3 of Set 11 | aksarka
# Processing Record 4 of Set 11 | port hawkesbury
# Processing Record 5 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 6 of Set 11 | beyneu
# Processing Record 7 of Set 11 | puerto madryn
# Processing Record 8 of Set 11 | kot isa khan
# Processing Record 9 of Set 11 | osijek
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | vestmanna
# Processing Record 12 of Set 11 | balaghat
# Processing Record 13 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 11 | brandon
# Processing Record 15 of Set 11 | mehamn
# Processing Record 16 of Set 11 | denpasar
# Processing Record 17 of Set 11 | mandurah
# Processing Record 18 of Set 11 | turukhansk
# Processing Record 19 of Set 11 | luganville
# Processing Record 20 of Set 11 | taksimo
# Processing Record 21 of Set 11 | boende
# Processing Record 22 of Set 11 | jijiga
# Processing Record 23 of Set 11 | manaus
# Processing Record 24 of Set 11 | flinders
# Processing Record 25 of Set 11 | beringovskiy
# Processing Record 26 of Set 11 | dingle
# Processing Record 27 of Set 11 | ust-ilimsk
# Processing Record 28 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 11 | claresholm
# Processing Record 30 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 31 of Set 11 | chase
# Processing Record 32 of Set 11 | turbat
# Processing Record 33 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | bezenchuk
# Processing Record 37 of Set 11 | vilhena
# Processing Record 38 of Set 11 | katsuura
# Processing Record 39 of Set 11 | cidreira
# Processing Record 40 of Set 11 | zaranj
# Processing Record 41 of Set 11 | cao bang
# Processing Record 42 of Set 11 | mahanoro
# Processing Record 43 of Set 11 | piranhas
# Processing Record 44 of Set 11 | alyangula
# Processing Record 45 of Set 11 | malanje
# Processing Record 46 of Set 11 | vagur
# Processing Record 47 of Set 11 | yatou
# Processing Record 48 of Set 11 | caninde
# Processing Record 49 of Set 11 | saquarema
# Processing Record 50 of Set 11 | presidencia roque saenz pena
# Processing Record 1 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | wakkanai
# Processing Record 4 of Set 12 | maua
# Processing Record 5 of Set 12 | cuenca
# Processing Record 6 of Set 12 | sangar
# Processing Record 7 of Set 12 | antofagasta
# Processing Record 8 of Set 12 | maniwaki
# Processing Record 9 of Set 12 | axixa do tocantins
# City not found. Skipping...
# Processing Record 10 of Set 12 | samarai
# Processing Record 11 of Set 12 | elizabeth city
# Processing Record 12 of Set 12 | harper
# Processing Record 13 of Set 12 | beisfjord
# Processing Record 14 of Set 12 | port hedland
# Processing Record 15 of Set 12 | noumea
# Processing Record 16 of Set 12 | los llanos de aridane
# Processing Record 17 of Set 12 | asyut
# Processing Record 18 of Set 12 | kambove
# Processing Record 19 of Set 12 | moroni
# Processing Record 20 of Set 12 | kletnya
# Processing Record 21 of Set 12 | tongliao
# Processing Record 22 of Set 12 | filadelfia
# Processing Record 23 of Set 12 | aripuana
# Processing Record 24 of Set 12 | puerto del rosario
# Processing Record 25 of Set 12 | sao gabriel da cachoeira
# Processing Record 26 of Set 12 | huarmey
# Processing Record 27 of Set 12 | presidente medici
# Processing Record 28 of Set 12 | da nang
# Processing Record 29 of Set 12 | kamiiso
# Processing Record 30 of Set 12 | road town
# Processing Record 31 of Set 12 | soni
# Processing Record 32 of Set 12 | langsa
# Processing Record 33 of Set 12 | concordia
# Processing Record 34 of Set 12 | vozhega
# Processing Record 35 of Set 12 | chipinge
# Processing Record 36 of Set 12 | tiznit
# Processing Record 37 of Set 12 | rudnogorsk
# Processing Record 38 of Set 12 | arauca
# Processing Record 39 of Set 12 | tsumeb
# Processing Record 40 of Set 12 | laval
# Processing Record 41 of Set 12 | seoul
# Processing Record 42 of Set 12 | vyshkov
# Processing Record 43 of Set 12 | vardo
# Processing Record 44 of Set 12 | surgut
# Processing Record 45 of Set 12 | evensk
# Processing Record 46 of Set 12 | saint-leu
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | sola
# Processing Record 49 of Set 12 | brodokalmak
# Processing Record 50 of Set 12 | longyan
# Processing Record 1 of Set 13 | emilio carranza
# Processing Record 2 of Set 13 | berlevag
# Processing Record 3 of Set 13 | bull savanna
# Processing Record 4 of Set 13 | camacha
# Processing Record 5 of Set 13 | san quintin
# Processing Record 6 of Set 13 | rameswaram
# Processing Record 7 of Set 13 | bonthe
# Processing Record 8 of Set 13 | concarneau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0  Deputatskiy      RU  2020-02-20 16:57:08  69.30  139.90     -5.33
# 1      Rikitea      PF  2020-02-20 16:57:09 -23.12 -134.97     79.03
# 2       Castro      BR  2020-02-20 16:57:09 -24.79  -50.01     83.97
# 3        Airai      TL  2020-02-20 16:57:10  -8.93  125.41     66.87
# 4    Mahebourg      MU  2020-02-20 16:57:10 -20.41   57.70     78.80
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        3.42
# 1        71          71        8.55
# 2        46          31        6.55
# 3        93          99        5.66
# 4        78          20        3.36

# %%
output_data_file = "weather_data/cities.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid =True
plt.savefig("weather_data/Fig1.png")
plt.show()

# %%
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid =True
plt.savefig("weather_data/Fig2.png")
plt.show()

# %%
plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid =True
plt.savefig("weather_data/Fig3.png")
plt.show()

# %%
plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Wind Speed (mph) "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid =True
plt.savefig("weather_data/Fig4.png")
plt.show()

# %%
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemi_df.head(2)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0  Deputatskiy      RU  2020-02-20 16:57:08  69.30  139.90     -5.33
# 5       Torbay      CA  2020-02-20 16:57:11  47.67  -52.73     23.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        3.42
# 5        62          75       32.21

# %%
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemi_df.head(2)
# Out:
#       City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 1  Rikitea      PF  2020-02-20 16:57:09 -23.12 -134.97     79.03        71
# 2   Castro      BR  2020-02-20 16:57:09 -24.79  -50.01     83.97        46
#
#    Cloudiness  Wind Speed
# 1          71        8.55
# 2          31        6.55

# %%
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere \n for Maximum Temperature", "Max Temp",(5,5))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Southern Hemisphere \n for Maximum Temperature", "Max Temp",(-50,90))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere \n for % Humidity", "% Humidity",(40,5))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Southern Hemisphere \n for % Humidity", "Humidity",(5,5))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere \n for Cloudiness", "Cloudiness",(40,5))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Southern Hemisphere \n for Cloudiness", "Cloudiness",(40,5))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere \n for Wind Speed", "Wind Speed",(10,40))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
    
plot_linear_regression(x_values, y_values,"Linear Regression on the Southern Hemisphere \n for Wind Speed", "Wind Speed",(-50,20))
